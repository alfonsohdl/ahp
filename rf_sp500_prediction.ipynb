# %%
import yfinance as yf #This package calls the Yahoo Finance API to download the data
import pandas as pd

sp500 = yf.Ticker("^GSPC")
sp500 = sp500.history(period="max") # This command will query all data from the very beginning when the index was created
sp500 # The columns shows: The opening price of that day, the lower and higher price on that day and the closing price of that day. +Volume traded that day.
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1927-12-30 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# 1928-01-03 00:00:00-05:00    17.760000    17.760000    17.760000    17.760000
# 1928-01-04 00:00:00-05:00    17.719999    17.719999    17.719999    17.719999
# 1928-01-05 00:00:00-05:00    17.549999    17.549999    17.549999    17.549999
# 1928-01-06 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# ...                                ...          ...          ...          ...
# 2023-08-11 00:00:00-04:00  4450.689941  4476.229980  4443.979980  4464.049805
# 2023-08-14 00:00:00-04:00  4458.129883  4490.330078  4453.439941  4489.720215
# 2023-08-15 00:00:00-04:00  4478.870117  4478.870117  4432.189941  4437.859863
# 2023-08-16 00:00:00-04:00  4433.790039  4449.950195  4403.549805  4404.330078
# 2023-08-17 00:00:00-04:00  4416.319824  4421.169922  4364.830078  4370.359863
#
# ...

# %%
sp500.index = pd.to_datetime(sp500.index).strftime('%Y-%m-%d')
sp500.index
# Out:
# Index(['1927-12-30', '1928-01-03', '1928-01-04', '1928-01-05', '1928-01-06',
#        '1928-01-09', '1928-01-10', '1928-01-11', '1928-01-12', '1928-01-13',
#        ...
#        '2023-08-04', '2023-08-07', '2023-08-08', '2023-08-09', '2023-08-10',
#        '2023-08-11', '2023-08-14', '2023-08-15', '2023-08-16', '2023-08-17'],
#       dtype='object', name='Date', length=24022)

# %%
sp500.plot.line(y="Close", use_index=True) # We are ploting the closing privce vs the date.
# Out:
# <Axes: xlabel='Date'>

# %%
del sp500["Dividends"] #Data cleaning removing the columns we do not need.
del sp500["Stock Splits"]

# %%
sp500["Tomorrow"] = sp500["Close"].shift(-1) #This columns shows tomorrow's price.

# %%
sp500["Target"] = (sp500["Tomorrow"] > sp500["Close"]).astype(int) # Our target/goal is to predict if tomorrow's price will be higher or lower than today's price.
# We convert a boolean into a integer using .astype(int).

# %%
sp500 #The target shows a 0 when the price went down and a 1 when price is greater thant yesterday's price.
# Out:
#                    Open         High          Low        Close      Volume  \
# Date
# 1927-12-30    17.660000    17.660000    17.660000    17.660000           0
# 1928-01-03    17.760000    17.760000    17.760000    17.760000           0
# 1928-01-04    17.719999    17.719999    17.719999    17.719999           0
# 1928-01-05    17.549999    17.549999    17.549999    17.549999           0
# 1928-01-06    17.660000    17.660000    17.660000    17.660000           0
# ...                 ...          ...          ...          ...         ...
# 2023-08-11  4450.689941  4476.229980  4443.979980  4464.049805  3753290000
# 2023-08-14  4458.129883  4490.330078  4453.439941  4489.720215  3896410000
# 2023-08-15  4478.870117  4478.870117  4432.189941  4437.859863  3832250000
# 2023-08-16  4433.790039  4449.950195  4403.549805  4404.330078  3753910000
# 2023-08-17  4416.319824  4421.169922  4364.830078  4370.359863  3943700000
#
#                Tomorrow  Target
# Date
# ...

# %%
sp500=sp500.loc["1990-01-01":].copy() # Using data from 1990 onwards, due to the fact that market conditions many years ago where probably too much different from now.

# %%
sp500
# Out:
#                    Open         High          Low        Close      Volume  \
# Date
# 1990-01-02   353.399994   359.690002   351.980011   359.690002   162070000
# 1990-01-03   359.690002   360.589996   357.890015   358.760010   192330000
# 1990-01-04   358.760010   358.760010   352.890015   355.670013   177000000
# 1990-01-05   355.670013   355.670013   351.350006   352.200012   158530000
# 1990-01-08   352.200012   354.239990   350.540009   353.790009   140110000
# ...                 ...          ...          ...          ...         ...
# 2023-08-11  4450.689941  4476.229980  4443.979980  4464.049805  3753290000
# 2023-08-14  4458.129883  4490.330078  4453.439941  4489.720215  3896410000
# 2023-08-15  4478.870117  4478.870117  4432.189941  4437.859863  3832250000
# 2023-08-16  4433.790039  4449.950195  4403.549805  4404.330078  3753910000
# 2023-08-17  4416.319824  4421.169922  4364.830078  4370.359863  3943700000
#
#                Tomorrow  Target
# Date
# ...

# %% [markdown]
# # Let's traing our machine learning model. Random forests work by training a bunch of individual decision trees with with randomized parameters and then averagin the results from those decision trees. Because of this process random forests are resistant to overfitting and also run relatively quickly and it can pick up non-linear tendencies in the data. For example, the open price is not linearly correlated with the target: If open price is 3000 versus 4000 there is no linear relationship between the open price and the target, if the open price is higher that doesn't mean the target will also be higher. Therefore, Random Forest can pick up non-linear correlations which in stock price prediction most of the relationships are non-linear.

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators=100, min_samples_split=100, random_state=1)

# n_estimators: number of decision trees.
# min_samples_split: protection against overfitting.
# random_state: generates predictable random numbers the second time in order to help us refine the model.

train = sp500.iloc[:-100] # all data except the last 100 rows
test = sp500.iloc[-100:]  # the last 100 rows

predictors = ["Close", "Volume", "Open", "High", "Low"]
model.fit(train[predictors], train["Target"]) # train the model using the predictors to predict the target
# Out:
# RandomForestClassifier(min_samples_split=100, random_state=1)

# %%
from sklearn.metrics import precision_score # What percentage of the time that we said that the market was going to go up acctually went up. 

preds = model.predict(test[predictors]) # Predict method.
preds = pd.Series(preds, index=test.index) # Turning an array into a panda's series.
precision_score(test["Target"], preds) # Precision score using the actual target and the predicted target.
# Out:
# 0.5645161290322581

# %%
combined = pd.concat([test["Target"], preds], axis=1) # Concatenating our target and our predictions.
combined.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
def predict(train, test, predictors, model): # Building a backtesting model. We want to test along multiple years of data (not only 100 rows)
    model.fit(train[predictors], train["Target"]) # fitting of the model
    preds = model.predict(test[predictors]) # generating our predictions
    preds = pd.Series(preds, index=test.index, name="Predictions") # combinining our model into a series
    combined = pd.concat([test["Target"], preds], axis=1) # combining everything together
    return combined

# %%
def backtest(data, model, predictors, start=2500, step=250): # backtest function which contains our data, model and predictors.
    all_predictions = [] # list with all data frames, each data frame is the predictions for a single years

    for i in range(start, data.shape[0], step): # function to loop across the data year by year
        train = data.iloc[0:i].copy() # this set is all the years previous to the current year.
        test = data.iloc[i:(i+step)].copy() # this set is the current year.
        predictions = predict(train, test, predictors, model) # predict function to generate our predictions
        all_predictions.append(predictions) # append all the predictions
    
    return pd.concat(all_predictions) # concatonate all the predictions

# start value is 2500, knowing that every years has aprox 250 trading days that means we are taking 10 years of data to backtest our model.
# step is 250, which means that we are training our model for about a year and the going to the next year, and the next year, and so on.
# Takinig the first 10 years of data and predicting values for the 11th year, then taking the first 11 years and predicting values for the 12th year...
# In this way we are getting predictions for many different years, increasing the confidence in our model.

# %%
predictions = backtest(sp500, model, predictors)

# %%
predictions["Predictions"].value_counts() # How many times each kind of prediction was made
# Out:
# Predictions
# 0    3433
# 1    2539
# Name: count, dtype: int64

# %%
precision_score(predictions["Target"], predictions["Predictions"]) # Precision score
# Out:
# 0.5289484048838126

# %%
predictions["Target"].value_counts() / predictions.shape[0] #Benchmark: What percentage of days the market actually went up (down)
# Out:
# Target
# 1    0.533657
# 0    0.466343
# Name: count, dtype: float64

# %%
horizons = [2,5,60,250,1000] # Creating a variaty of rolling averages
new_predictors = []

for horizon in horizons:
    rolling_averages = sp500.rolling(horizon).mean() # rolling average against the horizon
    
    ratio_column = f"Close_Ratio_{horizon}"
    sp500[ratio_column] = sp500["Close"] / rolling_averages["Close"]
    # the ratio between today's close and the average close in the last 2d, today's close and the average close in the last 5d, and so on.
    
    trend_column = f"Trend_{horizon}" # the number of the days in the pas "horizon" days tha the market actually went up.
    sp500[trend_column] = sp500.shift(1).rolling(horizon).sum()["Target"] # shifting forward to find the rolling sum of the target.
    # the sum of the number of days that the stock price actually went up.
    
    new_predictors += [ratio_column, trend_column] #adding these to new predictors.

# Letting know the algorithm if the current price market is greater than 2d, 1w, 3 months, 1 year, 4 years
# NaN when there is no data to calculate the rolling average.

# %%
sp500 = sp500.dropna()

# %%
sp500
# Out:
#                    Open         High          Low        Close      Volume  \
# Date
# 1993-12-14   465.730011   466.119995   462.459991   463.059998   275050000
# 1993-12-15   463.059998   463.690002   461.839996   461.839996   331770000
# 1993-12-16   461.859985   463.980011   461.859985   463.339996   284620000
# 1993-12-17   463.339996   466.380005   463.339996   466.380005   363750000
# 1993-12-20   466.380005   466.899994   465.529999   465.850006   255900000
# ...                 ...          ...          ...          ...         ...
# 2023-08-10  4487.160156  4527.370117  4457.919922  4468.830078  4504370000
# 2023-08-11  4450.689941  4476.229980  4443.979980  4464.049805  3753290000
# 2023-08-14  4458.129883  4490.330078  4453.439941  4489.720215  3896410000
# 2023-08-15  4478.870117  4478.870117  4432.189941  4437.859863  3832250000
# 2023-08-16  4433.790039  4449.950195  4403.549805  4404.330078  3753910000
#
# ...

# %%
model = RandomForestClassifier(n_estimators=200, min_samples_split=50, random_state=1) #Updating our model slighlty.

# %%
def predict(train, test, predictors, model):
    model.fit(train[predictors], train["Target"])
    preds = model.predict_proba(test[predictors])[:,1] # The probability of the stock price going up tomorrow
    preds[preds >=.6] = 1 # Threshold: The model has to be at least 60% confident in its prediction (that reduces the number of trading days)
    preds[preds <.6] = 0
    preds = pd.Series(preds, index=test.index, name="Predictions")
    combined = pd.concat([test["Target"], preds], axis=1)
    return combined

# %%
predictions = backtest(sp500, model, new_predictors)

# %%
predictions["Predictions"].value_counts()
# Out:
# Predictions
# 0.0    4152
# 1.0     819
# Name: count, dtype: int64

# %%
precision_score(predictions["Target"], predictions["Predictions"]) # On days the model says to buy the market goes up this % of time.
# Out:
# 0.568986568986569

# %%
predictions["Target"].value_counts() / predictions.shape[0]
# Out:
# Target
# 1    0.543553
# 0    0.456447
# Name: count, dtype: float64

# %%
predictions
# Out:
#             Target  Predictions
# Date
# 2003-11-14       0          0.0
# 2003-11-17       0          1.0
# 2003-11-18       1          1.0
# 2003-11-19       0          0.0
# 2003-11-20       1          1.0
# ...            ...          ...
# 2023-08-10       0          0.0
# 2023-08-11       1          0.0
# 2023-08-14       0          0.0
# 2023-08-15       0          0.0
# 2023-08-16       0          0.0
#
# [4971 rows x 2 columns]
